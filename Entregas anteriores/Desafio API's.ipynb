# %% [markdown]
# ### Análisis de Datos del Mercado de Criptomonedas con Binance API
#
# - En la era digital actual, el mercado de criptomonedas ha emergido como un campo fascinante y dinámico, ofreciendo oportunidades únicas para el análisis de datos y la comprensión de las tendencias del mercado financiero. Nuestro proyecto se centra en explorar este sector vibrante utilizando una de las herramientas más poderosas en el mundo de las criptomonedas: la API de Binance.
#
# - Binance, siendo una de las plataformas de intercambio de criptomonedas más grandes y reconocidas a nivel mundial, proporciona una API rica y robusta, permitiendo a los usuarios acceder a una amplia gama de datos del mercado en tiempo real. Esto incluye, pero no se limita a, datos históricos de precios, detalles de operaciones individuales, volúmenes de trading, y mucho más.
#
# - El objetivo principal de este proyecto es aprovechar estos datos para obtener insights valiosos sobre el comportamiento del mercado de Bitcoin (BTC), la criptomoneda líder en el mercado. Nos centraremos en extraer datos históricos de precios y operaciones de BTC comparados con el USD, analizando las tendencias, volatilidades y posibles patrones de trading.
#
# - Al final de este proyecto, esperamos tener un análisis detallado y multifacético del mercado de Bitcoin, brindando un panorama claro no solo para los entusiastas de las criptomonedas, sino también para aquellos interesados en las finanzas y la tecnología. Este desafío es una excelente oportunidad para sumergirnos en el mundo del análisis de datos financieros y abrir la puerta a futuras investigaciones y proyectos en este apasionante campo.

# %%
# paquetes necesarios
import requests
import pandas as pd
import hmac
import hashlib
import time
import matplotlib.pyplot as plt

# %%
api_key = '4BfPXEo2L55fb4WFe6EaNVVCl3JBuCyrEn75lM3y6R1Ut7HiLqTKBfBe5wquc85d'
api_secret = '9MZFj7DhnZTOViXtjMq7oupWg7aaN4bx7Xc7qb4ezPL0MOQt0IXKHLylYngFFPA0'
api_limit = 1000

# Función para firmar los parámetros
def sign_request(api_secret, params):
    query_string = '&'.join(["{}={}".format(d, params[d]) for d in params])
    signature = hmac.new(api_secret.encode(), query_string.encode(), hashlib.sha256).hexdigest()
    return signature

# Obtener operaciones históricas
def get_historical_trades(api_key, api_secret):
    url = "https://api.binance.com/api/v3/historicalTrades"
    params = {
        'symbol': 'BTCUSDT',
        'limit': api_limit
    }
    headers = {'X-MBX-APIKEY': api_key}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code != 200:
        print(f"Error en la solicitud de operaciones históricas: Código de estado {response.status_code}")
        print(response.text)
        return None
    else:
        return pd.DataFrame(response.json())

# Obtener precios históricos
def get_historical_prices(api_key, api_secret):
    url = "https://api.binance.com/api/v3/klines"
    params = {
        'symbol': 'BTCUSDT',
        'interval': '1h',
        'limit': api_limit
    }
    headers = {'X-MBX-APIKEY': api_key}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code != 200:
        print(f"Error en la solicitud de precios históricos: Código de estado {response.status_code}")
        print(response.text)
        return None
    else:
        data = response.json()
        columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume', 'Number of Trades', 'Taker Buy Base Asset Volume', 'Taker Buy Quote Asset Volume', 'Ignore']
        df = pd.DataFrame(data, columns=columns)
        df['Open Time'] = pd.to_datetime(df['Open Time'], unit='ms')
        df['Close Time'] = pd.to_datetime(df['Close Time'], unit='ms')
        return df

df_trades = get_historical_trades(api_key, api_secret)
df_prices = get_historical_prices(api_key, api_secret)

# %% [markdown]
# ## Unificar los 2 dataFrames en uno

# %%
df_trades['Time Interval'] = pd.to_datetime(df_trades['time'], unit='ms').dt.floor('H')

# conbinacion de dataframes
# Usamos un merge left para mantener todas las filas de df_trades y agregar la información correspondiente de df_prices
combined_df = pd.merge(df_trades, df_prices, left_on='Time Interval', right_on='Open Time', how='left')
combined_df.head()
# Out:
#            id           price         qty       quoteQty           time  \
# 0  3393197197  41939.44000000  0.04783000  2005.96341520  1706474757268
# 1  3393197198  41939.44000000  0.12102000  5075.51102880  1706474757268
# 2  3393197199  41939.44000000  0.02420000  1014.93444800  1706474757268
# 3  3393197200  41939.45000000  0.01354000   567.86015300  1706474757268
# 4  3393197201  41939.45000000  0.01354000   567.86015300  1706474757268
#
#    isBuyerMaker  isBestMatch       Time Interval           Open Time  \
# 0         False         True 2024-01-28 20:00:00 2024-01-28 20:00:00
# 1         False         True 2024-01-28 20:00:00 2024-01-28 20:00:00
# 2         False         True 2024-01-28 20:00:00 2024-01-28 20:00:00
# 3         False         True 2024-01-28 20:00:00 2024-01-28 20:00:00
# 4         False         True 2024-01-28 20:00:00 2024-01-28 20:00:00
#
#              Open            High             Low           Close  \
# 0  41785.91000000  41947.78000000  41681.72000000  41942.01000000
# 1  41785.91000000  41947.78000000  41681.72000000  41942.01000000
# 2  41785.91000000  41947.78000000  41681.72000000  41942.01000000
# 3  41785.91000000  41947.78000000  41681.72000000  41942.01000000
# 4  41785.91000000  41947.78000000  41681.72000000  41942.01000000
#
#          Volume              Close Time Quote Asset Volume  Number of Trades  \
# 0  969.94902000 2024-01-28 20:59:59.999  40551863.22311050             38155
# 1  969.94902000 2024-01-28 20:59:59.999  40551863.22311050             38155
# 2  969.94902000 2024-01-28 20:59:59.999  40551863.22311050             38155
# 3  969.94902000 2024-01-28 20:59:59.999  40551863.22311050             38155
# 4  969.94902000 2024-01-28 20:59:59.999  40551863.22311050             38155
#
#   Taker Buy Base Asset Volume Taker Buy Quote Asset Volume Ignore
# 0                561.34569000            23473870.24136250      0
# 1                561.34569000            23473870.24136250      0
# 2                561.34569000            23473870.24136250      0
# 3                561.34569000            23473870.24136250      0
# 4                561.34569000            23473870.24136250      0

# %%
combined_df.corr()
# Out:
#                                     id     price       qty  quoteQty  \
# id                            1.000000  0.003692  0.063619  0.063622
# price                         0.003692  1.000000 -0.098972 -0.098953
# qty                           0.063619 -0.098972  1.000000  1.000000
# quoteQty                      0.063622 -0.098953  1.000000  1.000000
# time                          0.950200 -0.144683  0.054872  0.054872
# isBuyerMaker                  0.220528  0.458515 -0.158420 -0.158414
# isBestMatch                        NaN       NaN       NaN       NaN
# Time Interval                      NaN       NaN       NaN       NaN
# Open Time                          NaN       NaN       NaN       NaN
# Open                               NaN       NaN       NaN       NaN
# High                               NaN       NaN       NaN       NaN
# Low                                NaN       NaN       NaN       NaN
# Close                              NaN       NaN       NaN       NaN
# Volume                             NaN       NaN       NaN       NaN
# Close Time                         NaN       NaN       NaN       NaN
# Quote Asset Volume                 NaN       NaN       NaN       NaN
# Number of Trades                   NaN       NaN       NaN       NaN
# Taker Buy Base Asset Volume        NaN       NaN       NaN       NaN
# Taker Buy Quote Asset Volume       NaN       NaN       NaN       NaN
# Ignore                             NaN       NaN       NaN       NaN
#
#                                   time  isBuyerMaker  isBestMatch  \
# id                            0.950200      0.220528          NaN
# price                        -0.144683      0.458515          NaN
# qty                           0.054872     -0.158420          NaN
# quoteQty                      0.054872     -0.158414          NaN
# time                          1.000000      0.122665          NaN
# isBuyerMaker                  0.122665      1.000000          NaN
# isBestMatch                        NaN           NaN          NaN
# Time Interval                      NaN           NaN          NaN
# Open Time                          NaN           NaN          NaN
# Open                               NaN           NaN          NaN
# High                               NaN           NaN          NaN
# Low                                NaN           NaN          NaN
# Close                              NaN           NaN          NaN
# Volume                             NaN           NaN          NaN
# Close Time                         NaN           NaN          NaN
# Quote Asset Volume                 NaN           NaN          NaN
# Number of Trades                   NaN           NaN          NaN
# Taker Buy Base Asset Volume        NaN           NaN          NaN
# Taker Buy Quote Asset Volume       NaN           NaN          NaN
# Ignore                             NaN           NaN          NaN
#
#                               Time Interval  Open Time  Open  High  Low  \
# id                                      NaN        NaN   NaN   NaN  NaN
# price                                   NaN        NaN   NaN   NaN  NaN
# qty                                     NaN        NaN   NaN   NaN  NaN
# quoteQty                                NaN        NaN   NaN   NaN  NaN
# time                                    NaN        NaN   NaN   NaN  NaN
# isBuyerMaker                            NaN        NaN   NaN   NaN  NaN
# isBestMatch                             NaN        NaN   NaN   NaN  NaN
# Time Interval                           NaN        NaN   NaN   NaN  NaN
# Open Time                               NaN        NaN   NaN   NaN  NaN
# Open                                    NaN        NaN   NaN   NaN  NaN
# High                                    NaN        NaN   NaN   NaN  NaN
# Low                                     NaN        NaN   NaN   NaN  NaN
# Close                                   NaN        NaN   NaN   NaN  NaN
# Volume                                  NaN        NaN   NaN   NaN  NaN
# Close Time                              NaN        NaN   NaN   NaN  NaN
# Quote Asset Volume                      NaN        NaN   NaN   NaN  NaN
# Number of Trades                        NaN        NaN   NaN   NaN  NaN
# Taker Buy Base Asset Volume             NaN        NaN   NaN   NaN  NaN
# Taker Buy Quote Asset Volume            NaN        NaN   NaN   NaN  NaN
# Ignore                                  NaN        NaN   NaN   NaN  NaN
#
#                               Close  Volume  Close Time  Quote Asset Volume  \
# id                              NaN     NaN         NaN                 NaN
# price                           NaN     NaN         NaN                 NaN
# qty                             NaN     NaN         NaN                 NaN
# quoteQty                        NaN     NaN         NaN                 NaN
# time                            NaN     NaN         NaN                 NaN
# isBuyerMaker                    NaN     NaN         NaN                 NaN
# isBestMatch                     NaN     NaN         NaN                 NaN
# Time Interval                   NaN     NaN         NaN                 NaN
# Open Time                       NaN     NaN         NaN                 NaN
# Open                            NaN     NaN         NaN                 NaN
# High                            NaN     NaN         NaN                 NaN
# Low                             NaN     NaN         NaN                 NaN
# Close                           NaN     NaN         NaN                 NaN
# Volume                          NaN     NaN         NaN                 NaN
# Close Time                      NaN     NaN         NaN                 NaN
# Quote Asset Volume              NaN     NaN         NaN                 NaN
# Number of Trades                NaN     NaN         NaN                 NaN
# Taker Buy Base Asset Volume     NaN     NaN         NaN                 NaN
# Taker Buy Quote Asset Volume    NaN     NaN         NaN                 NaN
# Ignore                          NaN     NaN         NaN                 NaN
#
#                               Number of Trades  Taker Buy Base Asset Volume  \
# id                                         NaN                          NaN
# price                                      NaN                          NaN
# qty                                        NaN                          NaN
# quoteQty                                   NaN                          NaN
# time                                       NaN                          NaN
# isBuyerMaker                               NaN                          NaN
# isBestMatch                                NaN                          NaN
# Time Interval                              NaN                          NaN
# Open Time                                  NaN                          NaN
# Open                                       NaN                          NaN
# High                                       NaN                          NaN
# Low                                        NaN                          NaN
# Close                                      NaN                          NaN
# Volume                                     NaN                          NaN
# Close Time                                 NaN                          NaN
# Quote Asset Volume                         NaN                          NaN
# Number of Trades                           NaN                          NaN
# Taker Buy Base Asset Volume                NaN                          NaN
# Taker Buy Quote Asset Volume               NaN                          NaN
# Ignore                                     NaN                          NaN
#
#                               Taker Buy Quote Asset Volume  Ignore
# id                                                     NaN     NaN
# price                                                  NaN     NaN
# qty                                                    NaN     NaN
# quoteQty                                               NaN     NaN
# time                                                   NaN     NaN
# isBuyerMaker                                           NaN     NaN
# isBestMatch                                            NaN     NaN
# Time Interval                                          NaN     NaN
# Open Time                                              NaN     NaN
# Open                                                   NaN     NaN
# High                                                   NaN     NaN
# Low                                                    NaN     NaN
# Close                                                  NaN     NaN
# Volume                                                 NaN     NaN
# Close Time                                             NaN     NaN
# Quote Asset Volume                                     NaN     NaN
# Number of Trades                                       NaN     NaN
# Taker Buy Base Asset Volume                            NaN     NaN
# Taker Buy Quote Asset Volume                           NaN     NaN
# Ignore                                                 NaN     NaN

# %% [markdown]
# ## Cambiar columnas de tipo bool a valores de cero o uno

# %%
# Lista de columnas de tipo bool
bool_columns = combined_df.select_dtypes(include=['bool']).columns

# Convertir cada columna bool a int
for column in bool_columns:
    combined_df[column] = combined_df[column].astype(int)

# Verificar los cambios
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1000 non-null   int64
#  1   price                         1000 non-null   object
#  2   qty                           1000 non-null   object
#  3   quoteQty                      1000 non-null   object
#  4   time                          1000 non-null   int64
#  5   isBuyerMaker                  1000 non-null   int32
#  6   isBestMatch                   1000 non-null   int32
#  7   Time Interval                 1000 non-null   datetime64[ns]
#  8   Open Time                     1000 non-null   datetime64[ns]
#  9   Open                          1000 non-null   object
#  10  High                          1000 non-null   object
#  11  Low                           1000 non-null   object
#  12  Close                         1000 non-null   object
#  13  Volume                        1000 non-null   object
#  14  Close Time                    1000 non-null   datetime64[ns]
#  15  Quote Asset Volume            1000 non-null   object
#  16  Number of Trades              1000 non-null   int64
#  17  Taker Buy Base Asset Volume   1000 non-null   object
#  18  Taker Buy Quote Asset Volume  1000 non-null   object
#  19  Ignore                        1000 non-null   object
# dtypes: datetime64[ns](3), int32(2), int64(3), object(12)
# memory usage: 148.6+ KB

# %% [markdown]
# ## Cambiar columnas del tipo Object a Float(float64)

# %%
object_columns_to_convert = [
    'price', 'qty', 'quoteQty', 'Open', 'High', 'Low', 
    'Close', 'Volume', 'Quote Asset Volume', 
    'Taker Buy Base Asset Volume', 'Taker Buy Quote Asset Volume', 'Ignore'
]

# Convertir cada columna seleccionada a float
for column in object_columns_to_convert:
    combined_df[column] = pd.to_numeric(combined_df[column], errors='coerce')

# Verificar los cambios
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1000 non-null   int64
#  1   price                         1000 non-null   float64
#  2   qty                           1000 non-null   float64
#  3   quoteQty                      1000 non-null   float64
#  4   time                          1000 non-null   int64
#  5   isBuyerMaker                  1000 non-null   int32
#  6   isBestMatch                   1000 non-null   int32
#  7   Time Interval                 1000 non-null   datetime64[ns]
#  8   Open Time                     1000 non-null   datetime64[ns]
#  9   Open                          1000 non-null   float64
#  10  High                          1000 non-null   float64
#  11  Low                           1000 non-null   float64
#  12  Close                         1000 non-null   float64
#  13  Volume                        1000 non-null   float64
#  14  Close Time                    1000 non-null   datetime64[ns]
#  15  Quote Asset Volume            1000 non-null   float64
#  16  Number of Trades              1000 non-null   int64
#  17  Taker Buy Base Asset Volume   1000 non-null   float64
#  18  Taker Buy Quote Asset Volume  1000 non-null   float64
#  19  Ignore                        1000 non-null   int64
# dtypes: datetime64[ns](3), float64(11), int32(2), int64(4)
# memory usage: 148.6 KB

# %% [markdown]
# ## Cambiar columnas del tipo fecha a milisegundos

# %%
# Lista de columnas de tipo datetime64[ns] que deseas convertir a milisegundos
datetime_columns = ['Time Interval', 'Open Time', 'Close Time']

# Convertir cada columna datetime a milisegundos
for column in datetime_columns:
    combined_df[column] = (combined_df[column].astype('int64') // 10**6)

# Verificar los cambios
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1000 non-null   int64
#  1   price                         1000 non-null   float64
#  2   qty                           1000 non-null   float64
#  3   quoteQty                      1000 non-null   float64
#  4   time                          1000 non-null   int64
#  5   isBuyerMaker                  1000 non-null   int32
#  6   isBestMatch                   1000 non-null   int32
#  7   Time Interval                 1000 non-null   int64
#  8   Open Time                     1000 non-null   int64
#  9   Open                          1000 non-null   float64
#  10  High                          1000 non-null   float64
#  11  Low                           1000 non-null   float64
#  12  Close                         1000 non-null   float64
#  13  Volume                        1000 non-null   float64
#  14  Close Time                    1000 non-null   int64
#  15  Quote Asset Volume            1000 non-null   float64
#  16  Number of Trades              1000 non-null   int64
#  17  Taker Buy Base Asset Volume   1000 non-null   float64
#  18  Taker Buy Quote Asset Volume  1000 non-null   float64
#  19  Ignore                        1000 non-null   int64
# dtypes: float64(11), int32(2), int64(7)
# memory usage: 148.6 KB

# %%
combined_df.sample(7)
# Out:
#              id     price      qty    quoteQty           time  isBuyerMaker  \
# 195  3393187446  41833.43  0.00182   76.136843  1706474219999             1
# 385  3393187636  41843.75  0.00116   48.538750  1706474240973             0
# 423  3393187674  41843.75  0.00048   20.085000  1706474248954             0
# 714  3393187965  41850.00  0.00127   53.149500  1706474280006             0
# 965  3393188216  41859.99  0.00353  147.765765  1706474302785             1
# 742  3393187993  41850.00  0.00727  304.249500  1706474284696             0
# 296  3393187547  41837.27  0.00021    8.785827  1706474234212             0
#
#      isBestMatch  Time Interval      Open Time      Open     High       Low  \
# 195            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 385            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 423            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 714            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 965            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 742            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
# 296            1  1706472000000  1706472000000  41785.91  41861.1  41681.72
#
#        Close     Volume     Close Time  Quote Asset Volume  Number of Trades  \
# 195  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 385  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 423  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 714  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 965  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 742  41861.1  733.14339  1706475599999        3.062654e+07             28214
# 296  41861.1  733.14339  1706475599999        3.062654e+07             28214
#
#      Taker Buy Base Asset Volume  Taker Buy Quote Asset Volume  Ignore
# 195                    407.45438                  1.702406e+07       0
# 385                    407.45438                  1.702406e+07       0
# 423                    407.45438                  1.702406e+07       0
# 714                    407.45438                  1.702406e+07       0
# 965                    407.45438                  1.702406e+07       0
# 742                    407.45438                  1.702406e+07       0
# 296                    407.45438                  1.702406e+07       0

# %%
# Cambiar el índice a la columna 'id'
combined_df.set_index('id', inplace=True)

# %%
final_DS = combined_df

# %%
final_DS.sample(7)
# Out:
#                price      qty    quoteQty           time  isBuyerMaker  \
# id
# 3393187606  41842.81  0.00240  100.422744  1706474238912             0
# 3393187253  41837.99  0.00021    8.785978  1706474204237             1
# 3393188062  41852.65  0.00003    1.255580  1706474294792             0
# 3393188066  41852.83  0.00014    5.859396  1706474294792             0
# 3393187449  41833.43  0.00141   58.985136  1706474220002             1
# 3393187451  41833.44  0.00240  100.400256  1706474220004             0
# 3393187696  41844.28  0.00020    8.368856  1706474248954             0
#
#             isBestMatch  Time Interval           Open Time      Open     High  \
# id
# 3393187606            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393187253            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393188062            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393188066            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393187449            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393187451            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
# 3393187696            1  1706472000000 2024-01-28 20:00:00  41785.91  41861.1
#
#                  Low    Close     Volume     Close Time  Quote Asset Volume  \
# id
# 3393187606  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393187253  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393188062  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393188066  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393187449  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393187451  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
# 3393187696  41681.72  41861.1  733.14339  1706475599999        3.062654e+07
#
#             Number of Trades  Taker Buy Base Asset Volume  \
# id
# 3393187606             28214                    407.45438
# 3393187253             28214                    407.45438
# 3393188062             28214                    407.45438
# 3393188066             28214                    407.45438
# 3393187449             28214                    407.45438
# 3393187451             28214                    407.45438
# 3393187696             28214                    407.45438
#
#             Taker Buy Quote Asset Volume  Ignore
# id
# 3393187606                  1.702406e+07       0
# 3393187253                  1.702406e+07       0
# 3393188062                  1.702406e+07       0
# 3393188066                  1.702406e+07       0
# 3393187449                  1.702406e+07       0
# 3393187451                  1.702406e+07       0
# 3393187696                  1.702406e+07       0

# %%
final_DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 3393187251 to 3393188250
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   price                         1000 non-null   float64
#  1   qty                           1000 non-null   float64
#  2   quoteQty                      1000 non-null   float64
#  3   time                          1000 non-null   int64
#  4   isBuyerMaker                  1000 non-null   int32
#  5   isBestMatch                   1000 non-null   int32
#  6   Time Interval                 1000 non-null   int64
#  7   Open Time                     1000 non-null   datetime64[ns]
#  8   Open                          1000 non-null   float64
#  9   High                          1000 non-null   float64
#  10  Low                           1000 non-null   float64
#  11  Close                         1000 non-null   float64
#  12  Volume                        1000 non-null   float64
#  13  Close Time                    1000 non-null   int64
#  14  Quote Asset Volume            1000 non-null   float64
#  15  Number of Trades              1000 non-null   int64
#  16  Taker Buy Base Asset Volume   1000 non-null   float64
#  17  Taker Buy Quote Asset Volume  1000 non-null   float64
#  18  Ignore                        1000 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int32(2), int64(5)
# memory usage: 148.4 KB
